# %% [markdown]
# <a href="https://colab.research.google.com/github/nagapandi1982/Colab-projects/blob/main/Deep_Learning_Sugar_Patient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv("https://raw.githubusercontent.com/nagapandi1982/Colab-projects/main/pima%20indians.txt", header=None)
X = data.iloc[:, 0:8]
y = data.iloc[:, 8]

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5652 - loss: 2.5950
# Epoch 2/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5770 - loss: 1.4164
# Epoch 3/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5892 - loss: 1.2362
# Epoch 4/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5989 - loss: 1.1382
# Epoch 5/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6253 - loss: 0.9077
# Epoch 6/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6152 - loss: 0.7975
# Epoch 7/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6596 - loss: 0.7795
# Epoch 8/100
# ...

# %%
input_labels = ["Pregnancies","Glucose","BloodPressure","SkinThickness","Insulin","BMI","Pedigree","Age"]
def draw_nn():
    fig, ax = plt.subplots(figsize=(10,6))
    input_y = list(range(8))
    hidden_y = [2,3,4,5]
    output_y = [3.5]
    for i,y in enumerate(input_y):
        ax.scatter(0,y,s=800)
        ax.text(-0.9,y,input_labels[i],fontsize=10)
    for y in hidden_y:
        ax.scatter(3,y,s=800)
    for y in output_y:
        ax.scatter(6,y,s=800)
        ax.text(6.3,y,"Diabetes",fontsize=11)
    for iy in input_y:
        for hy in hidden_y:
            ax.plot([0,3],[iy,hy])
    for hy in hidden_y:
        for oy in output_y:
            ax.plot([3,6],[hy,oy])
    ax.text(0,8,"Input Layer",fontsize=12)
    ax.text(3,8,"Hidden Layer",fontsize=12)
    ax.text(6,8,"Output Layer",fontsize=12)
    ax.axis("off")
    plt.show()
draw_nn()
